# %%
devtools::install_github("danicat/read.dbc")
# Out:
# Skipping install of 'read.dbc' from a github remote, the SHA1 (4cc8a390) has not changed since last install.
#   Use `force = TRUE` to force installation

# %%
library(read.dbc)

# %%
data <- read.dbc("DENGBR10.dbc")

# %%
data
# Out:
#         TP_NOT ID_AGRAVO DT_NOTIFIC SEM_NOT NU_ANO SG_UF_NOT ID_MUNICIP
# 1       2      A90       2010-01-26 201004  2010   26        260190
# 2       2      A90       2010-01-26 201004  2010   33        330455
# 3       2      A90       2010-01-11 201002  2010   17        170950
# 4       2      A90       2010-01-22 201003  2010   17        170950
# 5       2      A90       2010-01-25 201004  2010   31        314330
# 6       2      A90       2010-01-25 201004  2010   31        314330
# 7       2      A90       2010-01-29 201004  2010   31        314330
# 8       2      A90       2010-01-21 201003  2010   31        314330
# 9       2      A90       2010-01-25 201004  2010   31        314330
# 10      2      A90       2010-01-25 201004  2010   31        314330
# 11      2      A90       2010-01-28 201004  2010   31        314330
# 12      2      A90       2010-01-29 201004  2010   31        314330
# 13      2      A90       2010-01-28 201004  2010   31        314330
# ...
